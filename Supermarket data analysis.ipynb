# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import csv
df = pd.read_csv('supermarket_sales - Sheet1.csv', encoding = 'unicode_escape')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
print("The number of rows {} and columns {}".format(df.shape[0],df.shape[1]))
print(df.shape)
# Out:
# The number of rows 1000 and columns 17
# (1000, 17)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11412\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %% [markdown]
# It can be seen from data description and the heatmap that gross margin percentage has same value througout the dataset, since, there is no relation in between. So, we are droping 'gross margin percentage' column

# %%
df.drop(columns=['gross margin percentage'], axis = 1, inplace=True)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross income', 'Rating'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
sns.barplot(x="City",y="Total" , data = df)
# Out:
# <AxesSubplot: xlabel='City', ylabel='Total'>

# %%
sns.barplot(x="Branch",y="Total" , data = df)
# Out:
# <AxesSubplot: xlabel='Branch', ylabel='Total'>

# %% [markdown]
# There are 3 branches (A, B and C) of Supermarket in 3 cities "Yangon", "Mandalay" and "Naypyitaw" respectively. Sales of these three branches are almost similar, but, branch C i.e. in Naypyitaw has higher sales among them.

# %%
sns.barplot(x="Customer type",y="Total" , data = df)
# Out:
# <AxesSubplot: xlabel='Customer type', ylabel='Total'>

# %%
sns.barplot(x="Customer type",y="gross income" , data = df)
# Out:
# <AxesSubplot: xlabel='Customer type', ylabel='gross income'>

# %% [markdown]
# Members of the Supermarket do more shopping as compared to Normal people

# %%
sns.barplot(x="Customer type",y="Rating" , data = df)
# Out:
# <AxesSubplot: xlabel='Customer type', ylabel='Rating'>

# %%
plt.figure(figsize = (12,6))
df['Rating'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(df["Rating"])
# Out:
# <AxesSubplot: >

# %% [markdown]
# There are different ratings given by the Customers ranging from 4 to 10. However, mostly ratings are 6-7.

# %%
sns.barplot(x="Gender",y="gross income" , data = df)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='gross income'>

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
plt.figure(figsize = (12,6))
df['Product line'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Product line",y="Total" , data = df )
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Product line",y="gross income", data = df )
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='gross income'>

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Product line",y="Rating" , data = df )
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='Rating'>

# %%
df.groupby(['Product line'])['Unit price'].mean()
# Out:
# Product line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit price, dtype: float64

# %%
df.groupby(['Product line'])['Quantity'].mean()
# Out:
# Product line
# Electronic accessories    5.711765
# Fashion accessories       5.067416
# Food and beverages        5.471264
# Health and beauty         5.618421
# Home and lifestyle        5.693750
# Sports and travel         5.542169
# Name: Quantity, dtype: float64

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Product line",y="Total" , data = df , hue = "Gender")
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Product line",y="Rating" , data = df , hue = "Gender")
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='Rating'>

# %%
df['Payment'].value_counts().values
# Out:
# array([345, 344, 311], dtype=int64)

# %%
df['Payment'].value_counts().index
# Out:
# Index(['Ewallet', 'Cash', 'Credit card'], dtype='object')

# %%
df['Payment'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Payment",y="Total" , data = df)
# Out:
# <AxesSubplot: xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Payment",y="Total" , data = df , hue = "Gender")
# Out:
# <AxesSubplot: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# More payments are done by "Ewallet". "Credit card" is being used by lesser people.
